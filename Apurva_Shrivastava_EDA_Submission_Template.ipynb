# %% [markdown]
# <a href="https://colab.research.google.com/github/apurva-shrivastava/AirBnb-Booking-Analysis/blob/main/Apurva_Shrivastava_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - AirBnb Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**
# Airbnb platform connects people who want to rent out their homes or spare/extra room or space with people who are looking for accommodations in different locations.
#
# Airbnb offers people an easy and stress-free way to earn some income from their existing property round the globe.
#
# It has been observed that travellers often find Airbnb cheaper, has more character, and is homier than hotels or guest houses.
#
# Airbnb makes the bulk of its revenue by charging a rental fee for each booking.
#
# Their are millions of listing present on airBnb Platform and hence generate a lot of data.
#
# Data is an important factor and crucial factor for the company since it can be used for purposes like business decisions , guiding marketing initiatives ,understanding the behavioural pattern of customers and hosts and implementation of addittion services.
#
# In this project ,we'll be first focusing on data cleaning / regenrating to make data analysis ready and then  coming up with unique insights about different aspects of data and visualizing it by adopting different techniques from python libraries and drawing conclusions at last.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/apurva-shrivastava/AirBnb-Booking-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Their are numerous issues faced by both host and guests through out the process of booking/renting which can be curbed down by providing the exact same information needed by guests or hosts while booking such as location , area , facilities , fair price comparison , proper reviews and most relevent analysis which makes it easy for them to make the most relevent selection/choice.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Performing the right set of analysis in order to provide the relevent and sufficient information which can proved to be helpful while taking any sort of business decision or running any kind of marketing initiative which ultimately should be focussed towards success of business.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
air_df=pd.read_csv("/content/drive/MyDrive/Airbnb NYC 2019.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
air_df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f"Number of rows are :-  {air_df.shape[0]}")
print(f"Number of columns are :- {air_df.shape[1]}")
# Out:
# Number of rows are :-  48895
# Number of columns are :- 16

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(f"The duplicated value count is :- {len(air_df[air_df.duplicated()])}")
# Out:
# The duplicated value count is :- 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
air_df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
air_df.isnull().sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# 1.The Dataset contains 16 columns and 48895 records corresponding to airBnb Booking Analysis.
#
# 2.Out of 16 columns , their are 10 numerical column and 6 categorical or object type columns.
#
# 3.However we have null values associated with 4 columns namely name, host name , last review and review per month.
#
# 4.Their are no duplicated values in dataset.
#
# 5.The prices column cotanis some anamoly which needs to be rectified also  last_review column have data type data which is in string format, so we need to convert it into original format too.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
air_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
air_df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# id:-                  Unique Id for the listed property
#
# name:-                Name of the Listing
#
# host_id:-             unique id for the host of the property
#
# host_name:-           Name of the host
#
# neighbourhood_group:- location of property
#
# neighbourhood:-       area of the property
#
# latitude:-            latitude range
#
# longitude:-           longitude range
#
# room_type:-           type of property [private,shared,entire]
#
# price:-               rent of the property
#
# minimum_nights:-      min nights to be paid for
#
# number_of_reviews:-   total reviews made
#
# last_review:-         date of the last review
#
# reviews_per_month:-   average reviews
#
# calculated_host_listings_count:- total property per host
#
# availability_365:- available days around the year

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
air_df.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
#Creating a copy of the original dataset so as to perform manipulations and avoid altering the original data set
air_df_new=air_df.copy()

# %%
#filling null values in reviews_per_month column with zero
air_df_new['reviews_per_month'].fillna(0,inplace=True)

# %%
#filling null values in host_name column with "not known"
air_df_new['host_name'].fillna("Not Known",inplace=True)

# %%
#filling null values in name column with "not known"
air_df_new['name'].fillna("Not Known",inplace=True)

# %%
#converting the last_review column into its original datetime format and also creating a new dataframe zero null values for the same column
na_last_review_df=air_df_new[~air_df_new['last_review'].isnull()]
na_last_review_df.loc[na_last_review_df['last_review']!=0,'last_review']=na_last_review_df.loc[na_last_review_df['last_review']!=0,'last_review'].apply(lambda x : datetime.strptime(x,'%Y-%m-%d'))

# %%
#since we have lot of values as zero in price column which is an anomaly so creating a new dataframe where we are not considering the records with zero because prices could vary
air_df_new_price_notzero=air_df_new[air_df_new['price']!=0]

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Created a copy of original dataset.
#
# Did data cleaning and treated null values for the columns like host name , name , reviews per month.
#
# Coverted last review into date time type.
#
# Created new dataframe for prices (due to presence of anomaly) since it cant be replaced with median due to price unpredictability.
#
# Also their are values in columns availability_365 and minimum_nights which are outliers(quite high/low).

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# ### ***What is the average pricing of different room types and which room type is most expensive?***

# %%
#Chart - 1 visualization code 
air_df_new_price_notzero.groupby('room_type')['price'].mean().plot(kind='bar')
plt.title("room type v/s avg price")
plt.xlabel("room type")
plt.ylabel("prices")
# Out:
# Text(0, 0.5, 'prices')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I selected bar chart because its the most simplest and cleanest way to represent the variable having less unique value(room_type) and comparison among them becomes easy.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we found that the room type entire home/apt is highly priced on an average however shared room being the least priced.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes, according to customer preference we can suggest them with entire home/apt to earn high revenue and also for private room and shared room listing we can motivate hosts for further improvment.

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# ### ***how many properties were reviwed lastly every year and what were their prices ?***:

# %%
# Chart - 2 visualization code
na_last_review_df.groupby(na_last_review_df['last_review'].dt.year).agg({'host_id':'count','price':'mean'}).plot.bar(figsize=(10,10))
plt.title("distribution of number of properties and their prices across years")
plt.xlabel("years")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# we selected this chart because we had limited number of year distribution in dataset ranging from 2011-2019 , also bar graph simplifies the represtation of aggregate of two variables with respect to variation of a single variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# most of the properties were reviewed in the year 2019 and in the year 2013 prices of those properties were on a slightly higher side.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We observed that with time the more properties are coming up into picture and are being reviwed however low pricing can impact our business , we need to work on it upcoming years.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# ### ***what is the trend of average revenue generated by host considering the different properties they hold ?***

# %%
# Chart - 3 visualization code
air_df_new_price_notzero.groupby('calculated_host_listings_count')['price'].mean().plot(marker="^",color='red',figsize=(15,5))
plt.title("listings count and price trend for them")
plt.xlabel("No of properties")
plt.ylabel("price variation")
# Out:
# Text(0, 0.5, 'price variation')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this insight we wanted to represent two numerical variable and utlimately calculate average earning of the host having those properties so line chart represents these trends smoothly with accurate variation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we can see that host having properties ranging from 0-100 are almost priced in the same range however thier are certain highly priced properties are also present which is represted through spikes in between.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Their is no as as such insights which lead to negetive growth however we can see some highly priced spikes in between , maintaining them can uplift revenue.

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# ### ***How different properties in neighbourhood_group varies in terms of factors like price , minimum night booking , number of reviews and also the availability ?***

# %%
# Chart - 4 visualization code
air_df_new_price_notzero[['minimum_nights','price','number_of_reviews','neighbourhood_group','availability_365']].groupby("neighbourhood_group").mean().plot(figsize=(10,10), marker='o')
plt.title("variation across neighbourhood group")
plt.xlabel("Areas")
plt.ylabel("variations")
# Out:
# Text(0, 0.5, 'variations')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# line charts are generally helpful while we have to reflect or perform analysis across different variables and understand their trends acorss common factor ,in this case it is areas.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we could see that in terms of price the manhattan property has highest value,and bronx being the lowest,and in terms of average availability round the year , staten island takes the highest place and brooklyn being the lowest.however trend lines for number of reviews and min nights are kind of nearby.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# as we came across the factor that manhattan has highely priced properties but has average availabilty , if we could encourage hosts in this area to for more availability , it could lead to more turn over also number of reviews are less for this place.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# ### ***Show the distriburion of price in different neighbourhood for the host having highest number of holdings.***

# %%
# Chart - 5 visualization code
max_hold_df=air_df_new[air_df_new['host_name']==air_df_new.iloc[air_df_new['calculated_host_listings_count'].idxmax()]['host_name']]
max_hold_df.groupby('neighbourhood')['price'].sum().plot(kind='area',figsize=(10,5))
plt.title("Distribution of Revenue from different areas")
plt.xlabel("Areas")
plt.ylabel("Revenue")
# Out:
# Text(0, 0.5, 'Revenue')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# we picked the area chart because it lets us reflect upon the relationship between one categorical and numberical column , this shows very clearly how the revenue varies according to neighbourhood for that top host is a very clear manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The person earns most of the income/revenue from financial district area, murray hills follows by that , and chelsea and upper east side being lowest revenue generators.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# we should come with more listings in the financial district and recommend high paying customers properties over there however at the same time , we should conduct more research on the regions where property prices are low and contribute then to grow.

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# ### ***What is the percentage share of different room types and which room type had highest percentage share among all types ?***

# %%
# Chart - 6 visualization code
air_df_new['room_type'].value_counts().plot(kind='pie',legend=True,figsize=(10,10),autopct='%1.2f%%')
plt.title("Percentage Distribution of different kinds of room types preffered by guests")
# Out:
# Text(0.5, 1.0, 'Percentage Distribution of different kinds of room types preffered by guests')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We selected pie chart in order to provide clear division or proportion of different types of accomodation rooms preffered by the guests.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We came to the conclusion that guest generally prefer "entire home/apt" type accomodation however other categories such as private rooms are equally preferable but shared rooms are very rarely preffered.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We should promote or try to list more private or entire room type category since since it can help us to generate a good amount of customer satisfaction and also work on shared room to an extent.

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# ### ***What is the distribution of listing(AirBnb) across different areas/zones ?***

# %%
# Chart - 7 visualization code
air_df_new['neighbourhood_group'].value_counts().plot(kind='pie',legend=True,figsize=(10,10),autopct='%1.2f%%')
plt.title("Percentage Distribution of listings in different areas preffered by guests")
# Out:
# Text(0.5, 1.0, 'Percentage Distribution of listings in different areas preffered by guests')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This visualization provides a very clear view about the spread of different areas and what percentage of properties are listed within them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We could infer that the area manhattan has highest number of listings percentage followed by brooklyn and staten island has very less properties being listed but can ultimately lead to the conclusion that manhattan is the hub preffered by most of the travellers frequently.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# we should try registering more listing in the area such as stalen island so that it becomew easy easy for the guests snd uplift the business over such areas.

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# ### ***Express the percentage of properties reviewed across the years.***

# %%
# Chart - 8 visualization code
na_last_review_df['last_review'].dt.year.value_counts().plot(kind='pie', legend=True, autopct='%1.1f%%', startangle=180,figsize=(12,12))
plt.title("Percentage of properties reviewed acorss different years")
# Out:
# Text(0.5, 1.0, 'Percentage of properties reviewed acorss different years')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This represents the reviews distribution across each year very clearly and elaborative manner , i.e. what percetage of properties were reviewed every year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We could figure out that higest number of properties were reviewed in the years 2019 (exceptionally high) also the good thing is that percentage didnt got dipped , it has been increasing over the years.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We came to the conclusion that people before might not be aware about the feature of reviewing different properties or AirBnd might not be much trendy initially but gradully with upcoming years people beleived in providing valuable feedbacks and reviews.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# ### ***How property rates varies across different neighbourhood_group and are there any highly priced or exceptional cases present ?***

# %%
# Chart - 9 visualization code
plt.scatter('neighbourhood_group', 'price', s=26, c='red', marker='*',data=air_df_new_price_notzero)
plt.title("Rates of properties across areas")
plt.xlabel("Areas")
plt.ylabel("Rates")
# Out:
# Text(0, 0.5, 'Rates')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We used scatter plots in order to represnt a relational between one numerical and categorical variables and it shows outliers values too .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we figured out that the prices are high for the properties in the area manhanttan however their are exceptionally high properties present in other areas too like Queen Areas , brooklyn.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Taking it in a positive sense we can suggest guests higher priced properties depending on their paying capactiy and also increase the listing in other areas too.

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# ### ***How number of reviews varies with along with the properties listed by different host ?***

# %%
# Chart - 10 visualization code
plt.scatter('host_id', 'number_of_reviews', s=26, c='maroon', marker='^',data=air_df_new_price_notzero)
plt.title("variation of reviwed properties owned by different hosts")
plt.xlabel("number of hosts")
plt.ylabel("number of reviews")
# Out:
# Text(0, 0.5, 'number of reviews')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We selected scatter plot because it reflects dense areas of links between different properties by host id's and reviews in a scatterd manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we could see that are a couple of host for which the properties are reviewed exceptionally higher number of times and rest of the data is quite normal.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# we should encourage guest to get indulge in the process of reviewing the properties more since it will increase review ratings and help other customers to make more wise and suitable decisions and ultimately business to grow.

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# ### ***What is the availability round the year across different room types and areas ?***

# %%
# Chart - 11 visualization code
air_df_new_price_notzero.groupby(['room_type','neighbourhood_group'])['availability_365'].mean().unstack().plot(kind='box')
plt.title("availability across different neighbourhood_group")
plt.xlabel("areas")
plt.ylabel("availability round the year")
# Out:
# Text(0, 0.5, 'availability round the year')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Box plot shows clear distinction about spread of the variable , outliers if any and comparisons among various values of categorical variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we could see that their are no expectional outliers however the area stalen island has more spread of availability then compared to manhattan and brooklyn .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# we observed that availability round the year is less in manhattan area which is again most preffered places bu guests, we should focus on registering more places in this area which offers high availability round the year so that our business flourish too.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# ### ***What are the price variation across different room types and neighbourhood groups and are there any exceptionally high prices for some specific areas ?***

# %%
# Chart - 12 visualization code
air_df_new_price_notzero.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack().plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose box plot that we can get complete and proper distributions of numerical variable price in terms of unqiue values of categorical variables along with the outliers as reflected.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we could see that their are certain exceptionally highly priced room types in couple of neighbourhood_group , which can be inturn suggested to the customers capable of paying also entire home/apt tends to be more costly then compared to private/shared room.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# we should work on these exceptionally high priced properties and get their exact/fair values and reflect on them accordingly.

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# ### ***What is average room availability trend across different room types and areas ?***

# %%
# Chart - 13 visualization code
sns.distplot(air_df_new.groupby(['neighbourhood','room_type'])['availability_365'].mean(),hist=True)
# Out:
# <AxesSubplot:xlabel='availability_365', ylabel='Density'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We selected distribution plot to reflect distribution of how property availability varies across different areas and room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We could withness that availability round the year follows an approximate normal distribution trend (not exactly normal but apparently) , also not quite left or right skewed hence follows a decent distribution across areas in the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# According to the distribution availability has to be incresed in certain zones or areas which in turn can lead to more dense distribution.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %% [markdown]
# ## ***Reflect an correlation between different numerical columns of AirBnb dataset.***

# %%
# Correlation Heatmap visualization code
sns.heatmap(air_df_new[['number_of_reviews','price','latitude','longitude','availability_365','minimum_nights','reviews_per_month','calculated_host_listings_count']].corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We selected heatmap because it reflects very clear distinction and correlation between various numrical variables of dataset with proper scale.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# After exploring we came to the conclusion that their no as such colse correlation between columns , except for the columns like reviews_per_month and number_of_reviews which is pretty obvious.
#
# Also we could little correlation between number of reviews and availability and also availability and properties listed by same host which makes no difference.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %% [markdown]
# ### ***How prices varies across latitude and longtide of different neighbourhood_group areas?***

# %%
# Pair Plot visualization code
sns.pairplot(data=air_df_new, vars=['latitude','longitude','price'], hue="neighbourhood_group",height=8,aspect=2)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose pairplot to reflect  Multivariate Analysis i.e. presence of properties across various longitute and latitude and their price variations along with area name represnted by colours along with their own distributions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we found out the geographical locations of the areas present according to latitude and longitude which outputs a map like structure and price variations of listings in those areas.
#
# Their are many outliers present i.e some of the properties are  exceptionally  highly priced for many of the areas which is clearely visible over here.

# %% [markdown]
# ## Chart - 16

# %% [markdown]
# ### ***How prices varies according to the latitude and longitude of the area and the number of reviews for the property ?***

# %%
sns.distplot(air_df_new.groupby(['latitude','longitude','number_of_reviews'])['price'].mean(),hist=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# 1.Why did you pick the specific chart?

# %% [markdown]
# Distribution plot reflects the distribution of a numrical variable and here we want to check how avg price according to certain factors.

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?

# %% [markdown]
# We could see that the graph is right skewed which reflects that as most of the prices lies between a range of 0-1500 , since density is comparitively high.

# %% [markdown]
# 3.Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Here we get to know about price variation according to different latitude and longitude and also the reviews made about the properties.

# %% [markdown]
# ## Chart - 17

# %% [markdown]
# ### ***How rates of properties are getting impacted based on the number of reviews ?***

# %%
sns.jointplot(x='price', y='number_of_reviews', data=air_df_new, kind='scatter')

# %% [markdown]
# 1.Why did you pick the specific chart?

# %% [markdown]
# The scatter plot not only allow us to plot variations among two numerical values but also shows their individual distribution.

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?

# %% [markdown]
# We could figure out that some of the properties are outliers here and maximum ranges between 0-2000 and 0-150 for reviews .

# %% [markdown]
# 3.Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes , we can conclude that we do have varying set of properties listed which can serve the purpose of all different types of guests.

# %% [markdown]
# ## Chart - 18

# %% [markdown]
# ### ***Devise a distribution for properites which are available round the year and whatis the minimum nights they are available for ?***

# %%
sns.jointplot(x='availability_365', y='minimum_nights', data=air_df_new, kind='scatter')

# %% [markdown]
# 1.Why did you pick the specific chart?

# %% [markdown]
# We selected joint plot because it not only allow us to represnt a relationship between 2 numerical variables but also provides their individual distributions.

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?

# %% [markdown]
# We came to the conclusion that most of the properties offer for minimum nights ranging between 0-150 however their are many outliers values being indicated on the graph which needs to be taken care of, which shows exceptionally high values .

# %% [markdown]
# 3.Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Its a positive impact that we have wide variety of offerings for guests in terms of their preference for long or short stays accordingly.

# %% [markdown]
# ## Chart - 19

# %% [markdown]
# ### ***How different categories of room types varies on the basis of price and the reviews made acorss the years ?***

# %%
sns.pairplot(data=na_last_review_df, vars=['price','last_review'], hue="room_type",height=8,aspect=2)

# %% [markdown]
# 1.Why did you pick the specific chart?

# %% [markdown]
# we picked pair plot because it makes it very easy to reflect distribution of room types in terms of price across the years for reviewed properties and shows outliers values.

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?

# %% [markdown]
# we get to know that the room type "entire home/apt" is densly captures more or are rated more as year progress , the reason might be that people prefers more of them compared to other types like private or shared room.
#
# Also as we approach from 2007-2019 , we could withness slight increase in the rates of properties which is pretty obvious to state.
#
# However some of the private room types also have high rates too (outliers) .

# %% [markdown]
# ## Chart - 20

# %% [markdown]
# ### ***How types of rooms are distributed according to the availability round the year and reviews made ?***

# %%
sns.pairplot(data=na_last_review_df, vars=['last_review','availability_365',], hue="room_type",height=8,aspect=2)

# %% [markdown]
# 1.Why did you pick the specific chart?

# %% [markdown]
# we picked pair plot because its easy to reflect relationship between more then 3 columns i.e. quite useful for mutlivarite analysis.

# %% [markdown]
# 2.What is/are the insight(s) found from the chart?

# %% [markdown]
# we reached to the conclusion that their are certain outliers present in terms of the room types across all sort of years and are available in a wide variety of manners which satisfies each type of customer demand and preference.
#
# However as we move towards successive years we could witness more density.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# After proper analysis , we can suggest them to keep following things in mind:-
#
# 1.Since Manhattan area itself covers 44.30% of the maximum properties plus it consists most of the highly priced listings which utlimately makes it an tourist spot since it is prefered by most of the guests, also since minimum nights to be booked are high for this area.
#
# but we should focus more on making properties available for longer duration at such main attraction including brooklyn too and encourage people to review the property more(by providing rebooking points in return to that )since review rates are low.
#
#
# 2.We should encourage host to list more "Entire home/apt" room type since it is preffered 51.97% more by the visitors , also prices are ultimately high so it'll help to generate more revenue.
#
#
# 3.Properties in areas like  areas staten island and bronx are more reviwed by guests since but listing are less over here, which means it can turn out profitable for business if we focus to gather more hosts from these areas to list their properties.
#
#
# 4.From the hosts perspective, we can suggest them to rent their properties more in tourist prone areas by helping them with analysis report which in turn will improve their profit share and business can flourish too.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1.Out of the three types of room types i.e. private room (45.66 % presence rate) ,shared room (2.37% presence rate)and entire home/apartment(51.97% presence rate),the entire home/apartment tends for more costlier , where as shared rooms being lowest priced.
#
# 2.While analysing the trend of rates of properties across years , we came across in sudden hike in the prices of the properties which were lastly reviewed in the year 2013.
#
# 3.As AirBnb Started in the 2007 ,however from analysis we may reach to the conclusion to that hosts started trusting the process more from the year 2015 and as the time progresses finally in the year 2019 we could a sudden spike or rise in the listings of property in terms of reviews they got.
#
# 4.From dataset we got to know that their are many host who own more then one property as well ranging from 0-300 , however people owning properties between count of 0-50 have some of their property priced exceptionally high which might lead them to earn better revenue as compared to host having higher listings with less/decent prices , if opted by the guest.
#
# 5.The Manhattan (44.30% listings/properties ) area has most of the highly priced listings where as bronx being the lowest which makes manhattan an tourist spot prefered by most of the guests since minimum nights rates are also high for this area.
#
# 6.Though staten island has more availability scenes across the years and brooklyn(41.12% listings) being the lowest, reason might be host at staten island have more properties to rent for longer duration but it might not be tourist attraction.
# however we should focus more on making properties available for longer duration at main attraction such as manhattan and brooklyn too.
#
#
# 7.Properties located in areas staten island(0.76% listings)and bronx(2.23% listings ) are reviewed more by guests as compared to others i.e. they are trying to improve.
#
# 8.Though we witnessed that areas like brooklyn and Queens are less preffered by guests , however they too some exceptionally high properties ,which can be suggested to the custoner having higher paying capability.
#
# 9.Generally customer prefer a property lying between decent price range of 0-2000 dollars , since number of reviews are high for such properties however their are customer who dosent hesitate to invest or pay higher prices as well but they fall under minority.
#
# 10.From correlation heatmap , we could infer that generally people who choose to stay for a very longer period of time are likely(0.17%) to provide their reviews for that property.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
